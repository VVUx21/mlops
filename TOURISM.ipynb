# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Event_updated.csv")

# %%
df.head()

# %%
df['Month']

# %%
df.info()

# %%
dist=(df['Month'])
distset=set(dist)
dd=list(distset)
dictOfWords = {dd[i]: i for i in range(len(dd))}
df['Month'] = df['Month'].map(dictOfWords)

# %%
dist2=(df['location'])
distset=set(dist2)
dd=list(distset)
dictOfWords = {dd[i]: i for i in range(len(dd))}
df['location'] = df['location'].map(dictOfWords)

# %%
df.info()

# %%
df

# %%
import plotly.express as px

fig = px.scatter(df, x='Month', y='location')
fig.show()

# %%
x=df[['Month']]
y=df[['location']]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest= train_test_split(x,y,test_size=0.2, random_state=2)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn import tree

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression

regr=RandomForestRegressor(max_depth=2,random_state=0)
regr.fit(xtrain,ytrain)
print(regr.predict(xtest))

# %%
y_pred=regr.predict(xtest)

# %%
from sklearn.metrics import r2_score
r2_score(ytest,y_pred)

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Train a model (RandomForest in this case)
model = RandomForestClassifier(random_state=42)
model.fit(x_train, y_train)

# Make predictions
y_pred = model.predict(x_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

print(f"Accuracy: {accuracy:.2f}")

# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor
import joblib

def make_prediction(Month):
    # Create a NumPy array with the input features
    input_features = np.array([[Month]])

    # Make predictions using the loaded model
    prediction = regr.predict(input_features)

    # Round the prediction to the nearest integer and convert it to an integer
    rounded_prediction = int(np.round(prediction[0]))

    return rounded_prediction

# Example usage
input_feature1 = 7
output_prediction = make_prediction(input_feature1)

inverseDictOfWords = {v: k for k, v in dictOfWords.items()}

# Function to return location from an encoded number
def get_location(encoded_number):
    return inverseDictOfWords.get(encoded_number, "Unknown Location")

# Example usage
encoded_number = output_prediction
location = get_location(encoded_number)
print(f"The location for the encoded number {encoded_number} is: {location}")

# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor
import joblib

def make_prediction(Month):
    # Create a NumPy array with the input features
    input_features = np.array([[Month]])

    # Make predictions using the loaded model
    prediction = regr.predict(input_features)

    # Round the prediction to the nearest integer and convert it to an integer
    rounded_prediction = int(np.round(prediction[0]))

    return rounded_prediction


def get_location(output_prediction):
    return inverseDictOfWords.get(output_prediction, "Unknown Location")

input_feature1 = int(input("Enter the month (as a number)[Month to encoded number mapping : April: 0, June: 1 September: 2 December: 3 nan: 4 May: 5 November: 6 August: 7 July: 8 October: 9]: "))

# Make prediction
output_prediction = make_prediction(input_feature1)


inverseDictOfWords = {v: k for k, v in dictOfWords.items()}

# Get the location based on the predicted value
location = get_location(output_prediction)

# Show the result
print(f"The location for the encoded number {output_prediction} is: {location}")
